# %% [markdown]
# # 淘宝
# 职位描述：
# 1. 负责用户增长团队数据分析工作，打造用户增长团队数据一体化看板，为增长团队提供完整，全面，准确的商业洞察，并指导落地增长策略。
# 2. 通过业务专题分析模式，对业务问题进行深入拆解分析，沉淀分析思路与框架， 提炼数据产品需求，与相关团队（如技术开发团队） 协作并推动数据产品的落地。
# 3. 建立完整的AB实验验证机制，深度参与业务AB实验分析流程，有效提炼AB实验策略，与技术开发团队一同改善AB平台的精准性和有效性，实现增长实验的快速迭代。
# 4. 组织数据技术与产品相关的理念、技能、工具的培训，并分享到相关团队
#
# 职位要求：
# 1. 本科以上学历，统计、数学、计算机技术专业优先，2年以上的互联网行业经验。
# 2. 熟练使用SQL，Python/R等分析工具，有良好的的领域数据建模能力和业务拆解能力，具备数据可视化能力，独立产出数据分析报告，熟悉常用的数据挖掘/机器学习算法。
# 3. 熟悉完整的AB测试流程，熟练掌握参数估计方法，假设检验流程，了解不同检验方法的适用范围，熟悉相关的数理统计知识。
# 4. 具备较强的数据敏感度和业务洞察力，良好的沟通能力和跨团队协作能力与推动力，实验数据驱动业务的发展。
# 5. 具备用户增长相关背景知识的优先。
#
# 关键词：用户研究、数据分析、数据看板、数据产品
# <hr />
#
# 职位描述：
# 1. 基于业务场景进行专题分析，为业务决策和产品方案提供数据支持;
# 2. 规划整体解决方案，针对关键业务链路实现分析、监控、和预测，沉淀决策支持系统；
# 3. 通过深度分析和建模，探索创新型业务方向；
#
# 职位描述
# 1. 对数据敏感，对数据分析有强烈兴趣，善于学习新技术；
# 2. 具备优秀的数据建模能力，善于使用数据挖掘等手段建立数据模型解决实际问题；
# 3. 扎实的编程基础，有海量数据处理经验优先，熟悉R/Python语言优先；
# 4. 有用户行为分析、数据化运营、数据类产品规划等相关经验优先；
#
# 关键词：数据分析、数据服务、数据产品
# <hr />
#
# 工作职责：
# 1. 需要构建全面的、准确的、能反映闲鱼社区特征的整体指标体系, 并基于业务监控指标体系，及时发现与定位业务问题。
# 2. 通过专题分析，对闲鱼社区问题进行深入分析，为运营决策、产品方向提供数据支持
# 3. 沉淀分析思路与框架， 提炼数据产品需求，与工程团队协作并推动数据产品的落地。
# 4. 与相关团队协作进行数据建模工作，推动闲鱼社区业务的数据化运营
#
# 任职要求：
# 1. 统计、数学、信息技术、生物统计本科以上学历，3年左右相关工作经历
# 2. 熟练独立编写商业数据分析报告，及时发现和分析其中隐含的变化和问题
# 3. 良好的数据敏感度,能从海量数据提炼核心结果，有丰富的数据分析、挖掘、清洗和建模的经验
# 4. 熟练运用SQL，能高效的与数据技术团队进行沟通
# 5. 大项目的经验，有丰富的跨团队、部门的项目资源整合能力，能够独立开展研究项目
# 6. 有客户数据模型建立和运营经验、数据化运营经验、数据类产品类规划经验，尤其是互联网相关的优先
#
# 关键词：数据产品、数据分析、数据服务、用户研究
# <hr />
#
# 工作职责：
# 1. 协助构建全面的、准确的指标体系, 并基于业务监控指标体系，及时发现与定位业务问题
# 2. 通过专题分析，对业务问题进行深入分析，为业务与技术团队决策提供数据支持
# 3. 与相关团队协作进行数据建模工作，推动部门的数据化运营
#
# 任职要求：
# 1. 统计、数学、信息技术、生物统计本科以上学历，3年以上相关工作经历
# 2. 熟练独立编写商业数据分析报告，及时发现和分析其中隐含的变化和问题
# 3. 良好的数据敏感度,能从海量数据提炼核心结果，有丰富的数据分析经验
# 4. 熟练运用SQL，能高效的与数据技术团队进行沟通
#
# 关键词: 数据产品、数据分析、数据服务

# %% [markdown]
# # 字节跳动
# 工作职责：
# 1. 负责分析剪映、轻颜、Faceu等字节跳动旗下国内影像业务数据分析工作；
# 2. 根据用户行为数据进行增长相关分析，搭建指标体系，建立增长分析模型，建设并迭代报表体系；
# 3. 与产品、运营、研发等紧密配合，推进落地带来业务提升；
# 4. 独立完成专项分析，从数据处理分析、数据指标设计到方案评估的工作闭环
#
# 任职要求：
# 1. 本科及以上学历，数学、统计学、计算机相关专业优先；
# 2. 熟练使用Hive，精通SQL/Excel/Python/R等工具；
# 3. 具备结构化思维，较强学习能力和创造力，有用户同理心以及数据敏感度；
# 4. 对统计学有较深的理解，有 Growth Hacking、AB 实验、数据建模经验者优先。
#
# 关键词：影像、用户研究、数据产品、数据分析
# <hr />
#
# 工作职责：
# 1. 负责业务指标体系建设；
# 2. 负责日常业务运营数据分析，多维度/多模型地全面刻画业务数据状态；
# 3. 负责从海量用户产生的海量数据中深入统计分析，挖掘用户行为，挖掘用户属性。
#
# 任职要求：
# 1. 本科以上学历，计算机、数据专业优先；
# 2. 熟悉hive，spark等大数据开发工具；
# 3. 熟悉sql, tableau等数据处理和分析工具；
# 4. 数据逻辑清晰，沟通能力强，业务理解能力强；
# 5. 有构建数据仓库经验者优先；
# 6. 有构建数据仓库、BI应用、互联网行业数据挖掘分析经验者优先;
#
# 关键词：数据产品、数据分析、数据挖掘、用户研究
# <hr />
#
# 工作职责：
# 1. 规划视觉业务销售业绩目标，根据团队情况对销售目标进行拆解和发放；
# 2. 针对目标设计考核体系，并及时跟踪过程指标，确保结果指标达成；
# 3. 对核心数据，包括业绩和客户数据进行收集、分析和统计，提供相应的运营策略建议。
#
# 任职要求：
# 1. 本科及以上学历，信息管理、统计学、经济学等专业优先，2年以上工作经验；
# 2. 熟练使用excel、PPT等office工具，熟悉SQL语句优先，对数据有较强的敏感度，具有一定的数据分析方法论；
# 3. 具备跨部门沟通和项目管理经验优先；
# 4. 执行力强，具备较强的逻辑思维、流程思维和服务意识，目标导向型，自我驱动型，优秀的快速学习能力
#
# 关键词：视觉、数据产品、数据分析
# <hr />
#
# 工作职责：
# 1. 负责商业化日常数据统计分析，针对异常情况进行跟踪和深入分析，数据驱动支持业务决策；
# 2. 建设业务分析或机器学习模型，不断评估和优化模型；
# 3. 数据报表展现及数据产品设计；
# 4. 支持业务方及团队内部数据需求；
#
# 任职要求：
# 1. 本科及以上学历，计算机、统计、数学相关专业优先；对数据分析有强烈兴趣者优先；
# 2. 精通 SQL，熟悉数据spark、hive等数据库工具，了解数据仓库、数据可视化，有大型互联网公司数据分析经验、互联网数据建模分析经验者优先；
# 3. 熟练使用 Python/R进行数据清洗、分析，熟悉常用的数据统计和分析方法；
# 4. 加分项：掌握 Tableau、PowerBI等数据可视化工具；
# 5. 能快速理解业务，发掘业务细节和数据之间的联系；
# 6. 抗压能力强，沟通协调推动能力强，积极主动，肯思考；
#
# 关键词：数据分析、数据产品、数据支持、数据挖掘
# <hr />
#
# 工作职责：
# 1. 深入理解商业化和广告审核业务，运用数据挖掘、机器学习、深度学习等技术，帮助提升广告审核效率；
# 2. 内部数据产品如机器学习平台、爬虫等的开发和维护；
# 3. 支持业务方及团队内部的开发需求。
#
# 任职要求：
# 1. 熟练掌握Hadoop、MapReduce、Hive、Spark等大数据处理工具/框架；
# 2. 精通Python语言，有扎实的数据结构和算法功底，有工程实现能力；
# 3. 熟悉常用的机器学习算法如LR/决策树/Kmeans等；熟练使用深度学习框架 TensorFlow/Pytorch/Keras其中的一种或者多种，了解深度网络中各种结构如RNN/CNN/Attention的原理和作用；
# 4. 持续学习，保持跟进深度学习领域最新研究方向。对前沿深度学习模型如Bert/GPT/GAN等网络了解者优先
#
# 关键词：广告、数据挖掘、数据开发
# <hr />
#
# 工作职责：
# 1. 负责公司旗下各产品用户增长、渠道推广业务的数据分析工作；
# 2. 搭建和优化业务分析模型，反映渠道推广效果、用户行为及成本状况，指导增长策略；
# 3. 监控业务数据，分析业务发展态势，发现并定位数据异常原因，提供预警和解决方案；
# 4. 理解产品细节，基于数据为业务发展提供决策建议，跨部门协同推进优化方案落地。
#
# 任职要求：
# 1. 本科及以上学历，统计、数学、计算机相关专业；
# 2. 2年以上数据分析工作经验，熟练掌握Hive/SQL，精通Excel，掌握Tableau等BI工具尤佳；
# 3. 结构化思维，对数据敏感，自我驱动强，能通过数据主动发现问题并解决问题；
# 4. 关注互联网产品及发展变化，理解互联网业务逻辑，具备抽象思维能力，能将重复的工作自动化
#
# 关键词：用户研究、数据分析、数据产品
# <hr />
#
# 工作职责：
# 1. 负责抖音/火山/直播等多款产品的策略相关数据分析工作；
# 2. 梳理业务核心逻辑，构建能够刻画业务当前状态的数据体系；
# 3. 对互联网某几项领域有深入的了解，能从行业趋势和产品形态等角度，给业务方方向与业务模式的建议；
# 4. 全面分析各项影响产品提升与增长的因素，各项业务细节，结合业务方向，给出可落地的整体的产品优化方案；
# 5. 区别传统回答问题型分析师，希望能够解决问题，针对一个业务方向，能够找出其中问题，产出策略，推动落地执行
#
# 任职要求：
# 1. 数学、统计学、计算机相关专业优先，对数据分析有强烈兴趣者优先；
# 2. 好奇心强，求知欲强，有钻研探索精神，对数据分析有强烈兴趣者优先；
# 3. 有互联网公司数据分析，产品经理，运营经理，策略经理等多方面经验者优先；
# 4. 创新能力强，面对业务上各种新问题，能创造性的发明新的分析优化方案者优先；
# 5. 性格严谨细致认真
#
# 关键词：视频、数据分析、数据产品

# %% [markdown]
# # 腾讯
# 工作职责：
# 1. 通过数据分析对营销活动等提供数据支撑，包括并不限于活动效果评估、用户画像、LTV评估及流失预测等
# 2. 构建和维护完善的运营数据分析报表，为日常运营提供相关的数据支持和洞察，保证数据对业务的针对性、逻辑性、准确性和可读性
# 3. 通过数据挖掘和探索，从用户参与营销活动、产品购买和使用、游戏游玩等行为进行深入的行为分析等，主动发现和识别问题，为产品或运营提供优化建议
# 4. 深入理解业务的基础上，参与各类数据提取、处理、分析、建模，为产品数据化运营提供系统化解决方案
#
# 任职要求：
# 1. 计算机科学，信息科学，统计学等相关专业本科及以上
# 2. 3 +年数据分析建模的相关工作经验，最好有游戏行业背景，熟悉数字化营销和CRM方面的数据分析应用
# 3. 至少熟练使用以下任一种分析工具SAS/R/Python,有独立的模型开发经验
# 4. 有海量数据分析处理经验及大数据分析平台的使用经验，至少熟练掌握一种查询工具（SQL、hive）
# 5. 工作细致耐心、积极主动，有强烈的责任感，有较好的文字、数据、图表呈现能力。善于沟通、合作，有出色的理解力和执行能力
#
# 关键词：运营、数据分析、数据产品
# <hr />
#
# 工作职责：
# 1. 负责运营成本的数据分析工作，搭建数据分析模型和预测模型。
# 2. 负责运营成本的预算核算管理工作，结合业务资源需求和运营模式；
# 3. 负责提供成本优化建议方案，并执行应用于实际业务。
#
# 任职要求：
# 1. 本科以上学历，数学、统计学、计算机等理工科专业，以复合财务管理、经济等专业优先，3年以上数据分析经验；
# 2. 敏锐的数据洞察力、严谨的逻辑思维能力，善于分析、归纳、解决问题，并能量化数据建模；
# 3. 熟练Mysql数据库，熟悉Python等进行数据提取和处理工作，熟悉业界主流BI产品（如PowerBI、tableau等）；
# 4. 有较好的报告撰写能力，良好的沟通，人际交往能力，以及出色的团队合作精神；
# 5. 具备CPA/ACCA等专业资格优先。
#
# 关键词：财务、数据分析
# <hr />
#
# 工作职责：
# 1. 理解用户体验改善和精细化营销的需求，构建用户画像特征系统， 运用统计建模和机器学习方法解决复杂的游戏业务问题，基于海量数据分析挖掘有效特征，提升模型效果；
# 2. 负责对业务和管理层解释算法设计、模型应用，阐述商业价值，提供决策建议。
#
# 任职要求：
# 1. 3年以上数据处理、分析相关项目经验；
# 2. 统计、数学、计算机、计量经济学及相关专业硕士或博士学历；
# 3. 扎实的数理统计和机器学习基础、 熟悉GLM、多元统计分析、贝叶斯模型、实验设计、随机森林、Boosting、聚类、关联性分析、时间序列分析等；
# 4. 熟悉SQL、R和python；
# 5. 自我驱动，有突出的研究分析、创新学习和沟通合作能力，能解决问题并落地；
# 6. 熟悉hadoop/spark/ hive/ hbase等一个或多个分布式计算框架和数据库技术。
#
# 关键词：用户研究、数据挖掘
# <hr />
#
# 工作职责：
# 1. 负责创新项目数据分析，规划搭建数据指标体系和分析体系，依靠数据来帮助团队挖掘增长目标；
# 2. 使用统计学分析方法、挖掘算法，构建数据分析模型来驱动增长；
# 3. 设计AB方案，推断挖掘影响业务增长的核心因素，制定优化策略并协同推进落地；
# 4. 与产品、工程、算法团队配合，深度参与产品增长计划，依据数据分析结果帮助团队确定目标和优先级；
# 5. 深入理解用户侧产品，围绕用户获取、激活、留存、ARPU等问题，设计搭建完善的数据体系，驱动业务的发展。
#
# 任职要求：
# 1. 本科及以上学历，理工类相关专业，统计、数学、计算机、经济等专业；
# 2. 有数据库、数据仓库的处理经验，熟练使用SQL，掌握SQL/Tableau/R；
# 3. 有扎实的编程能力和坚实的工程能力，熟悉python，hadoop，hive，spark等；
# 4. 对数据敏感，善于从数据中发现疑点，深入理解用户侧产品的数据指标体系；
# 5. 有包括不限于搜索/广告/信息流/短视频/社区/社交等用户产品的产品、运营、数据分析、研发经验者优先；
# 6. 熟悉增长黑客(Growth Hacking)，或对此有强烈兴趣者优先；
# 7. 较强的独立工作能力和协调能力，较强的逻辑性和分析能力，具有敬业精神和团队精神，擅于沟通，有良好的人际关系，很强的好奇心、钻研精神。
# 8. 执行力强，对工作有责任心，富有创新意识，对产品有野心。
#
# 关键词：用户研究、数据产品、数据挖掘
# <hr />
#
# 工作职责：
# 1. 负责业务基础数据建设，优化完善事件上报、指标体系和数据仓库，建立完备高效的数据体系；
# 2. 负责业务指标数据日常监控、异动分析、实验分析以及专项分析，提供深度的业务insight和策略优化举措，进而推动落地闭环。同时可沉淀分析方法与工具；
# 3. 负责推进数据工具建设，协同工程团队搭建flink、clickhouse等实时/离线监控工具、敏捷分析平台、细查平台等数据应用产品；
# 4. 持续关注所在业务所在行业动态、产品创新、内容流行，为决策者提供行业及战略布局的分析报告。
#
# 任职要求：
# 1. 计算机、数学相关专业硕士及以上学历，三年以上工作经验，博士优先。
# 2. 有扎实的统计理论基础，熟练掌握SQL，了解常用的数据结构和算法；有Hadoop、flink、clickhouse等平台处理经验更佳；
# 3. 良好的数据分析能力，有丰富实操经验，包含业务分析，用户分析，市场分析，产品研究、用户调研等；
# 4. 要求良好团队合作精神，良好的逻辑思维、业务意识和沟通能力，抗压能力强；
#
# 关键词：数据产品、数据分析
# <hr />
#
# 工作职责：
# 1. 负责CSIG整体营销数据采集、清洗、分析、可视化等相关工作，保证数据质量；
# 2. 基于对业务的理解，梳理和设计数据指标体系，建立数据分析模型，辅助营销决策；
# 3. 对内外部数据进行分析，挖掘影响营销效果的核心因素，沉淀成方法论并进行营销实践；
# 4. 针对重大营销事件进行数据挖掘，用数据支持活动营销策略，效果跟踪，进行业务助力；
#
# 任职要求：
# 1. 5年以上营销数据分析相关工作经验，在互联网公司、咨询公司具有营销分析经验优先；
# 2. 需要具备有数据采集、清洗、分析等项目经验者，有To b营销经验优先；
# 3. 有一定的数据库基础和数据建模经验，并具有良好的实操经验；熟练使用Hive，R、Python等数据分析工具；
# 4. 良好的沟通表达能力、执行力强，对待工作认真严谨和负责；
#
# 关键词：数据开发、数据产品、数据分析
